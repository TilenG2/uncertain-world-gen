# %%
import utils
import ploting
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 from ..scripting.utils import generate_world, generate_world_pandas
#       2 from ..scripting.ploting import draw_combined_world
#
# ImportError: attempted relative import with no known parent package

# %%
seed = 123456
number_of_features = 2
feature_bounds = (0, 1) # set min an max value for all features
class_number = 3

# stoping criteria for building trees
endArea = 0.4 # the lower the number more complex are world ideal range [0, 0.4]
max_depth = 4 # when to stop building the tree 4 works well

# observerd world parameters i sudgets you generate thees yourself use generate_world_pandas and then your own method for 'ov' and 'unc'
errRange = 0.1
corr = 1

#generate_world returns a 2d np.array like
# Class, True Value 1, True Value 2, Observed Value 1, Uncertainty 1, Observed Value 2, Uncertainty 2
world = utils.generate_world(seed, number_of_features, 
                             feature_bounds=feature_bounds,
                             endArea=endArea,
                             max_depth=max_depth,
                             class_number=class_number,
                             errRange = errRange,
                             corr = corr
)
ploting.draw_combined_world(world)

# %%
utils.generate_world_pandas(seed, number_of_features, feature_bounds=feature_bounds, endArea=endArea, max_depth=max_depth, class_number=class_number)
# Out:
#       Class  True Value 1  True Value 2
# 0       2.0      0.377348      0.646761
# 1       2.0      0.369957      0.853997
# 2       0.0      0.766786      0.440198
# 3       2.0      0.445302      0.846939
# 4       2.0      0.503913      0.527026
# ...     ...           ...           ...
# 9995    0.0      0.203908      0.220470
# 9996    2.0      0.732833      0.454002
# 9997    1.0      0.688337      0.047507
# 9998    0.0      0.959807      0.952654
# 9999    0.0      0.915029      0.405461
#
# [10000 rows x 3 columns]
